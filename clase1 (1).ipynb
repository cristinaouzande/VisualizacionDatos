# %% [markdown]
# # Clase 1 - Introduccion a Python

# %%
print('hola')
# Out:
# hola

# %%
import numpy as np

# %%
x = 50
numeros_aleatorios = np.random.rand(x)
print(numeros_aleatorios)
# Out:
# [0.83283793 0.39944022 0.64818119 0.50004907 0.41269941 0.10688196
#  0.53285141 0.69341407 0.45560185 0.11554648 0.58527208 0.73976486
#  0.55527618 0.62492795 0.25813016 0.86380392 0.84281584 0.41818855
#  0.08950092 0.59993322 0.85592244 0.96792767 0.01935731 0.91225983
#  0.74257283 0.57946367 0.46674371 0.3625612  0.99927849 0.14972508
#  0.57992484 0.37437349 0.87030316 0.70104477 0.91454276 0.0958573
#  0.16247737 0.98700762 0.82327771 0.31843298 0.15592653 0.36761918
#  0.79624668 0.6726017  0.66658184 0.16642171 0.3197417  0.01137227
#  0.59279597 0.02135883]

# %%
# %ls datasets
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          mic.xlsx

# %% [markdown]
# ## Tipos de los datos

# %%
import math

# %%
type(4)
# Out:
# int

# %%
type(4.0)
# Out:
# float

# %%
type(-3)
# Out:
# int

# %%
type(x)
# Out:
# int

# %%
x = 'nombre1'
x
# Out:
# 'nombre1'

# %%
type(x)
# Out:
# str

# %%
numbers = [1,2,3,4,5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type(numbers)
# Out:
# list

# %%
numbers[4]
# Out:
# 5

# %%
sum_ = sum(numbers)
sum_
# Out:
# 15

# %%
lenth = len(numbers)
lenth
# Out:
# 5

# %%
promedio = sum_/lenth
promedio
# Out:
# 3.0

# %%
type(3/5)
# Out:
# float

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
type(math.pi)
# Out:
# float

# %%
type('math.pi')
# Out:
# str

# %%
numbers_ = [math.pi, 3/5, 4.0, 'nombre', True]
numbers_
# Out:
# [3.141592653589793, 0.6, 4.0, 'nombre', True]

# %%
type(True)
# Out:
# bool

# %%
print(True)
# Out:
# True

# %%
type('True')
# Out:
# str

# %%
print(None)
# Out:
# None

# %%
type(None)
# Out:
# NoneType

# %%
x = 6
y = 8
if x < y:
    print ('{} es menor que {}'.format(x,y))
else:
    print(x, 'es mayor que' , y)
# Out:
# 6 es menor que 8

# %%
unalista= [True, 6<5, 1==3, None is None]
unalista
# Out:
# [True, False, False, True]

# %% [markdown]
# ## el uso de for loop

# %%
for element in unalista:
    print(element,'\t', type(element))
# Out:
# True 	 <class 'bool'>
# False 	 <class 'bool'>
# False 	 <class 'bool'>
# True 	 <class 'bool'>

# %% [markdown]
# # lista

# %%
unaLista = ['first','second','third','fourth','fifth', 'sixth']
unaLista
# Out:
# ['first', 'second', 'third', 'fourth', 'fifth', 'sixth']

# %%
#unaLista.sort()
#unaLista

# %%
unaLista[:2]
# Out:
# ['first', 'second']

# %%
unaLista[:]
# Out:
# ['first', 'second', 'third', 'fourth', 'fifth', 'sixth']

# %%
unaLista[1:3] #sin incluir el elemento en la posicion 3
# Out:
# ['second', 'third']

# %%
unaLista[5]
# Out:
# 'sixth'

# %%
unaLista[-1]
# Out:
# 'sixth'

# %%
unaLista[-1:-3]
# Out:
# []

# %%
unaLista[-3:-1] #sin incluir el elemento en la posicion -1
# Out:
# ['fourth', 'fifth']

# %%
unaLista[-3]
# Out:
# 'fourth'
