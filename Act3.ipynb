# %% [markdown]
# ## Actividad 3 - A00827306

# %%
import pandas as pd
import numpy as np

# %%
# %ls
# Out:
#  00_00_binder.ipynb                    'clase1 (1).ipynb'
#  00_00_primer_pasos.ipynb               clase1.ipynb
#  01_01_data_types.ipynb                 clase2.ipynb
#  01_02_read_iloc_unique_groupby.ipynb   clase2pt2.ipynb
#  02_00_data_wrangling.ipynb             clase3.ipynb
#  02_01_null_display.ipynb              'clase 3 pt2.ipynb'
#  02_02_basic_math.ipynb                 datasets/
#  Act3.ipynb                             README.md
#  adult.csv                              requirements.txt
#  antropometria-dataset-2.csv            Untitled.ipynb

# %%
df = pd.read_csv('antropometria-dataset-2.csv')
df.head()
# Out:
#     folio  intp  entidad          desc_ent  sexo  edad  meses   peso  ropa  \
# 0  210295     2       21            PUEBLA     2    38      8  73.70     2
# 1  101655     3       10           DURANGO     2    11     11  35.65     2
# 2   10287     6        1    AGUASCALIENTES     2    18      8  54.80     1
# 3   91526     4        9  DISTRITO FEDERAL     1    10      8  33.40     2
# 4  210939     3       21            PUEBLA     2    19      3  97.95     2
#
#    talla  ... hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis  \
# 0  146.4  ...    16:30      2     16:35            1     R2101        5
# 1  145.1  ...    15:25      3     15:25            1     M1041        1
# 2  162.0  ...     9:40      1      9:40            1     M0108        5
# 3  146.5  ...     7:40      3      7:45            1     M0931        4
# 4  161.0  ...     6:00      2      6:00            1     M2123        5
#
#   est_urb est_marg       pondef  est_var
# ...

# %%
df.columns
# Out:
# Index(['folio', 'intp', 'entidad', 'desc_ent', 'sexo', 'edad', 'meses', 'peso',
#        'ropa', 'talla', 'emb', 'temb', 'cintura', 'cadera', 'sistol',
#        'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
#        'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var'],
#       dtype='object')

# %%
my_pivot = pd.pivot_table(df, 
                          index = 'desc_ent', 
                          values = 'peso',
                          aggfunc = 'mean'
                         )
my_pivot
# Out:
#                                       peso
# desc_ent
# AGUASCALIENTES                   66.357786
# BAJA CALIFORNIA                  68.467270
# BAJA CALIFORNIA SUR              71.809198
# CAMPECHE                         65.418475
# CHIAPAS                          57.613775
# CHIHUAHUA                        66.656005
# COAHUILA DE ZARAGOZA             68.154142
# COLIMA                           68.743648
# DISTRITO FEDERAL                 65.119273
# DURANGO                          66.354922
# GUANAJUATO                       63.936390
# GUERRERO                         60.466315
# HIDALGO                          59.995917
# JALISCO                          66.697270
# MEXICO                           60.680850
# MICHOACAN DE OCAMPO              64.900000
# MORELOS                          63.541295
# NAYARIT                          66.541827
# NUEVO LEON                       67.239853
# OAXACA                           58.800067
# ...

# %%
my_pivot = pd.pivot_table(df, 
                          index = 'desc_ent', 
                          values = 'peso',
                          aggfunc = 'mean',
                          columns = 'sexo'
                         )
my_pivot
# Out:
# sexo                                     1          2
# desc_ent
# AGUASCALIENTES                   69.985381  63.254292
# BAJA CALIFORNIA                  71.391818  65.893667
# BAJA CALIFORNIA SUR              75.561015  68.168959
# CAMPECHE                         68.622637  62.920493
# CHIAPAS                          58.365222  57.096111
# CHIHUAHUA                        68.892642  64.815295
# COAHUILA DE ZARAGOZA             68.873094  67.467348
# COLIMA                           70.998878  66.978393
# DISTRITO FEDERAL                 69.460661  61.654128
# DURANGO                          68.846451  64.400031
# GUANAJUATO                       65.008000  63.100995
# GUERRERO                         62.611437  58.899850
# HIDALGO                          61.747958  58.972554
# JALISCO                          67.076482  66.418111
# MEXICO                           63.140314  58.887882
# MICHOACAN DE OCAMPO              66.374612  63.784311
# ...

# %% [markdown]
# Despues de realizar las tablas pivote para los datos de antropometria, puedo concluir que la informacion se ve mas ordenada de esta manera ya que podemos observar el peso promedio por estado en la primera tabla pivote, y el peso promedio por sexo en la segunda tabla pivote. Es un claro ejemplo de como podemos utilizar la programación para hacer un breve analisis y visualización de nuestros datos.

# %%
# %ls
# Out:
#  00_00_binder.ipynb                    'clase1 (1).ipynb'
#  00_00_primer_pasos.ipynb               clase1.ipynb
#  01_01_data_types.ipynb                 clase2.ipynb
#  01_02_read_iloc_unique_groupby.ipynb   clase2pt2.ipynb
#  02_00_data_wrangling.ipynb             clase3.ipynb
#  02_01_null_display.ipynb              'clase 3 pt2.ipynb'
#  02_02_basic_math.ipynb                 datasets/
#  Act3.ipynb                             README.md
#  adult.csv                              requirements.txt
#  antropometria-dataset-2.csv            Untitled.ipynb

# %%
ds = pd.read_csv('adult.csv')
ds.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country the label
# ...

# %%
ds.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'the label'],
#       dtype='object')

# %%
pivot2 = pd.pivot_table(ds, 
                        index = ['education', 'sex'],
                        values = 'age',
                        aggfunc = 'median',
                        columns = 'marital-status'
                       )
pivot2
# Out:
# marital-status          Divorced   Married-AF-spouse   Married-civ-spouse  \
# education     sex
#  10th          Female       45.0                 NaN                 32.0
#                Male         39.0                 NaN                 48.0
#  11th          Female       41.0                 NaN                 42.0
#                Male         38.0                 NaN                 41.0
#  12th          Female       41.0                 NaN                 34.0
#                Male         41.0                 NaN                 41.5
#  1st-4th       Female       64.0                 NaN                 44.5
#                Male         63.0                 NaN                 51.0
#  5th-6th       Female       53.0                 NaN                 43.0
#                Male         56.0                 NaN                 46.0
#  7th-8th       Female       52.0                 NaN                 46.0
# ...
