# %% [markdown]
# # Actividad 5: Visualización con Histogramas & Boxplots

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#pip install seaborn

# %%
# %ls
# Out:
#  00_00_binder.ipynb
#  00_00_primer_pasos.ipynb
#  01_01_data_types.ipynb
#  01_02_read_iloc_unique_groupby.ipynb
#  02_00_data_wrangling.ipynb
#  02_01_null_display.ipynb
#  02_02_basic_math.ipynb
#  Act3.ipynb
# 'Actividad 5.ipynb'
# 'Actividad 6 - Presentación Intermedia (1).ipynb'
#  adult.csv
#  antropometria-dataset-1.csv
#  antropometria-dataset-2.csv
# 'clase1 (1).ipynb'
#  clase1.ipynb
#  clase2.ipynb
#  clase2pt2.ipynb
#  clase3.ipynb
# 'clase 3 pt2.ipynb'
#  Clase4.ipynb
#  clase5.ipynb
#  datasets/
#  README.md
#  requirements.txt
#  Untitled.ipynb
# 'winequality-red.xls - winequality-red.csv'

# %%
df=pd.read_csv('antropometria-dataset-1.csv')
df.head()
# Out:
#     folio  intp  entidad          desc_ent  sexo  edad  meses   peso  ropa  \
# 0  210295     2       21            PUEBLA     2    38      8  73.70     2
# 1  101655     3       10           DURANGO     2    11     11  35.65     2
# 2   10287     6        1    AGUASCALIENTES     2    18      8  54.80     1
# 3   91526     4        9  DISTRITO FEDERAL     1    10      8  33.40     2
# 4  210939     3       21            PUEBLA     2    19      3  97.95     2
#
#    talla  ... hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis  \
# 0  146.4  ...    16:30      2     16:35            1     R2101        5
# 1  145.1  ...    15:25      3     15:25            1     M1041        1
# 2  162.0  ...     9:40      1      9:40            1     M0108        5
# 3  146.5  ...     7:40      3      7:45            1     M0931        4
# 4  161.0  ...     6:00      2      6:00            1     M2123        5
#
#   est_urb est_marg       pondef  est_var
# ...

# %% [markdown]
# #  box plot, line plot, histogramas de las variables peso, cintura

# %% [markdown]
# ## Box plots

# %%
sns.boxplot(data=df['peso']
           ) #boxplots de todo

# %%
sns.boxplot(data=df['edad']
           ) #boxplots de todo

# %%
sns.histplot(df.peso)

# %%
sns.histplot(df.cintura)

# %%
df.plot(kind='line')

# %%
my_pivot1 = pd.pivot_table(df, 
                          index = 'desc_ent', 
                          values = 'peso',
                          aggfunc = 'median',
                          columns = 'sexo',
                          margins = True
                         )
my_pivot
# Out:
# sexo                                  1       2     All
# desc_ent
# AGUASCALIENTES                   89.425  88.150  88.500
# BAJA CALIFORNIA                  89.800  88.250  88.800
# BAJA CALIFORNIA SUR              92.500  90.000  91.200
# CAMPECHE                         91.000  87.225  88.600
# CHIAPAS                          79.925  83.225  82.100
# CHIHUAHUA                        88.500  88.000  88.200
# COAHUILA DE ZARAGOZA             89.000  90.800  90.300
# COLIMA                           91.300  90.250  91.150
# DISTRITO FEDERAL                 90.350  86.600  88.000
# DURANGO                          89.600  87.600  88.400
# GUANAJUATO                       85.500  89.000  87.000
# GUERRERO                         81.750  87.100  85.325
# HIDALGO                          83.950  85.000  84.150
# JALISCO                          87.275  89.175  88.225
# MEXICO                           83.900  83.950  83.900
# MICHOACAN DE OCAMPO              87.800  89.050  88.100
# ...

# %%
sns.boxplot(data=my_pivot1)

# %%
my_pivot2 = pd.pivot_table(df, 
                          index = 'desc_ent', 
                          values = 'cintura',
                          aggfunc = 'median',
                          columns = 'sexo'
                         )
my_pivot2
# Out:
# sexo                                  1       2
# desc_ent
# AGUASCALIENTES                   89.425  88.150
# BAJA CALIFORNIA                  89.800  88.250
# BAJA CALIFORNIA SUR              92.500  90.000
# CAMPECHE                         91.000  87.225
# CHIAPAS                          79.925  83.225
# CHIHUAHUA                        88.500  88.000
# COAHUILA DE ZARAGOZA             89.000  90.800
# COLIMA                           91.300  90.250
# DISTRITO FEDERAL                 90.350  86.600
# DURANGO                          89.600  87.600
# GUANAJUATO                       85.500  89.000
# GUERRERO                         81.750  87.100
# HIDALGO                          83.950  85.000
# JALISCO                          87.275  89.175
# MEXICO                           83.900  83.950
# MICHOACAN DE OCAMPO              87.800  89.050
# MORELOS                          88.450  88.000
# NAYARIT                          87.150  86.050
# ...

# %%
my_pivot2.plot()

# %%
my_pivot3 = pd.pivot_table(df, 
                          index = ['desc_ent'],
                          values = 'sistol',
                          aggfunc = 'median',
                          columns = 'sexo'
                         )
my_pivot3
# Out:
# sexo                                   1        2
# desc_ent
# AGUASCALIENTES                   123.000  118.000
# BAJA CALIFORNIA                  120.000  114.875
# BAJA CALIFORNIA SUR              120.000  114.500
# CAMPECHE                         120.000  110.000
# CHIAPAS                          113.750  110.000
# CHIHUAHUA                        120.000  114.000
# COAHUILA DE ZARAGOZA             120.000  113.000
# COLIMA                           115.000  110.000
# DISTRITO FEDERAL                 113.000  110.000
# DURANGO                          120.000  119.000
# GUANAJUATO                       118.875  116.500
# GUERRERO                         116.000  115.000
# HIDALGO                          120.000  114.500
# JALISCO                          118.625  115.000
# MEXICO                           115.000  110.000
# MICHOACAN DE OCAMPO              119.625  115.500
# MORELOS                          114.000  111.000
# NAYARIT                          120.000  115.000
# ...

# %%
plt.bar(
# Out:
# <BarContainer object of 1 artists>

# %%
sns.histplot(df['cadera'],
             kde = False).set_title('Histogram of caderas')
# Out:
# Text(0.5, 1.0, 'Histogram of caderas')

# %%
my_pivot4 = pd.pivot_table(df,
                           index='desc_ent',
                           values='ropa',
                           columns = 'sexo',
                           aggfunc = 'sum',
                          )
my_pivot4
# Out:
# sexo                               1    2
# desc_ent
# AGUASCALIENTES                   493  579
# BAJA CALIFORNIA                  402  466
# BAJA CALIFORNIA SUR              415  440
# CAMPECHE                         350  443
# CHIAPAS                          378  540
# CHIHUAHUA                        415  526
# COAHUILA DE ZARAGOZA             417  439
# COLIMA                           410  543
# DISTRITO FEDERAL                 247  298
# DURANGO                          425  515
# GUANAJUATO                       467  590
# GUERRERO                         431  570
# HIDALGO                          311  518
# JALISCO                          352  479
# MEXICO                           269  370
# MICHOACAN DE OCAMPO              408  543
# MORELOS                          361  554
# NAYARIT                          400  542
# NUEVO LEON                       427  530
# OAXACA                           372  551
# PUEBLA                           358  518
# ...

# %%
my_pivot4top10=my_pivot4.sort_values(by = 1,
                                     ascending = False,
                                     axis = 0)
my_pivot4top10=my_pivot4top10.head(10)
my_pivot4top10.drop([2],inplace=True, axis=1)
my_pivot4top10
# Out:
# sexo                               1
# desc_ent
# SAN LUIS POTOSI                  537
# QUERETARO                        496
# AGUASCALIENTES                   493
# GUANAJUATO                       467
# VERACRUZ DE IGNACIO DE LA LLAVE  454
# SONORA                           432
# GUERRERO                         431
# NUEVO LEON                       427
# DURANGO                          425
# TABASCO                          421

# %%
my_pivot4top10.plot(kind='barh',figsize=(15,8))
