# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          mic.xlsx

# %%
import pandas as pd
import numpy as np

# %%
#pip install xlrd para leer un archivo de xlsx

# %%
#pip install openpyxl

# %%
df = pd.read_excel('datasets/Canada.xlsx',
                   engine = 'openpyxl',
                   skiprows = range (20),
                   sheet_name = 'Canada by Citizenship'
                  )
df.head()
# Out:
#          Type    Coverage          OdName   AREA AreaName     REG  \
# 0  Immigrants  Foreigners     Afghanistan  935.0     Asia  5501.0
# 1  Immigrants  Foreigners         Albania  908.0   Europe   925.0
# 2  Immigrants  Foreigners         Algeria  903.0   Africa   912.0
# 3  Immigrants  Foreigners  American Samoa  909.0  Oceania   957.0
# 4  Immigrants  Foreigners         Andorra  908.0   Europe   925.0
#
#            RegName    DEV             DevName  1980  ...    2012    2013  \
# 0    Southern Asia  902.0  Developing regions  16.0  ...  2635.0  2004.0
# 1  Southern Europe  901.0   Developed regions   1.0  ...   620.0   603.0
# 2  Northern Africa  902.0  Developing regions  80.0  ...  3774.0  4331.0
# 3        Polynesia  902.0  Developing regions   0.0  ...     0.0     0.0
# 4  Southern Europe  901.0   Developed regions   0.0  ...     1.0     1.0
#
#    Unnamed: 43  Unnamed: 44  Unnamed: 45  Unnamed: 46  Unnamed: 47  \
# ...

# %%
df.shape
# Out:
# (1015, 51)

# %%
df.columns
# Out:
# Index([    'REG', 'RegName',     'DEV', 'DevName',      1980,      1981,
#             1982,      1983,      1984,      1985,      1986,      1987,
#             1988,      1989,      1990,      1991,      1992,      1993,
#             1994,      1995,      1996,      1997,      1998,      1999,
#             2000,      2001,      2002,      2003,      2004,      2005,
#             2006,      2007,      2008,      2009,      2010,      2011,
#             2012,      2013],
#       dtype='object')

# %%
df.drop([ 'Type', 'Coverage', 'AREA', 'AreaName','Unnamed: 43',
       'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47',
       'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50'],
        axis = 1, 
        inplace = True )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_126/2096300581.py in <module>
#       3        'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50'],
#       4         axis = 1,
# ----> 5         inplace = True )
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
df.columns
# Out:
# Index([    'REG', 'RegName',     'DEV', 'DevName',      1980,      1981,
#             1982,      1983,      1984,      1985,      1986,      1987,
#             1988,      1989,      1990,      1991,      1992,      1993,
#             1994,      1995,      1996,      1997,      1998,      1999,
#             2000,      2001,      2002,      2003,      2004,      2005,
#             2006,      2007,      2008,      2009,      2010,      2011,
#             2012,      2013],
#       dtype='object')

# %%
df.columns
# Out:
# Index([    'REG', 'RegName',     'DEV', 'DevName',      1980,      1981,
#             1982,      1983,      1984,      1985,      1986,      1987,
#             1988,      1989,      1990,      1991,      1992,      1993,
#             1994,      1995,      1996,      1997,      1998,      1999,
#             2000,      2001,      2002,      2003,      2004,      2005,
#             2006,      2007,      2008,      2009,      2010,      2011,
#             2012,      2013],
#       dtype='object')

# %%
df.rename(columns = {'RegName':'Continent'},
          inplace = True)

# %%
df.columns
# Out:
# Index([      'REG', 'Continent',       'DEV',   'DevName',        1980,
#               1981,        1982,        1983,        1984,        1985,
#               1986,        1987,        1988,        1989,        1990,
#               1991,        1992,        1993,        1994,        1995,
#               1996,        1997,        1998,        1999,        2000,
#               2001,        2002,        2003,        2004,        2005,
#               2006,        2007,        2008,        2009,        2010,
#               2011,        2012,        2013],
#       dtype='object')

# %%
df['Total']= df.iloc[:, 4:].sum(axis=1)
#df.iloc[:, 4:]
# df.loc[:, '1980':0] #hay que cambiar a str

# %%
df.head(2)
# Out:
#       REG        Continent    DEV             DevName  1980  1981  1982  1983  \
# 0  5501.0    Southern Asia  902.0  Developing regions  16.0  39.0  39.0  47.0
# 1   925.0  Southern Europe  901.0   Developed regions   1.0   0.0   0.0   0.0
#
#    1984   1985  ...    2005    2006    2007    2008    2009    2010    2011  \
# 0  71.0  340.0  ...  3436.0  3009.0  2652.0  2111.0  1746.0  1758.0  2203.0
# 1   0.0    0.0  ...  1223.0   856.0   702.0   560.0   716.0   561.0   539.0
#
#      2012    2013    Total
# 0  2635.0  2004.0  58639.0
# 1   620.0   603.0  15699.0
#
# [2 rows x 39 columns]

# %%
df.iloc[0:1,-1]
# Out:
# 0    58639.0
# Name: Total, dtype: float64

# %%
#df = df.setindex('Country', inplace = True)

# %%
#df

# %%
#df.loc['Japan', 'Total]

# %%
#df.loc['Japan']

# %%
df.columns
# Out:
# Index([      'REG', 'Continent',       'DEV',   'DevName',        1980,
#               1981,        1982,        1983,        1984,        1985,
#               1986,        1987,        1988,        1989,        1990,
#               1991,        1992,        1993,        1994,        1995,
#               1996,        1997,        1998,        1999,        2000,
#               2001,        2002,        2003,        2004,        2005,
#               2006,        2007,        2008,        2009,        2010,
#               2011,        2012,        2013,     'Total'],
#       dtype='object')

# %%
df.columns= list(map(str,df.columns))

# %%
df.columns
# Out:
# Index(['REG', 'Continent', 'DEV', 'DevName', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992',
#        '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', 'Total'],
#       dtype='object')
