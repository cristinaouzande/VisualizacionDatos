# %% [markdown]
# ## Actividad 2: Base de Datos

# %% [markdown]
# ## Escribe el nombre que caracteriza el conjunto de datos
#
# Calidad del Vino
#
# ## Escribe el organismo que lo generó
#
# UCI Machine Learning Repository
#
# ## Incluye un enlace de Internet de dónde se pueden descargar en línea y envíalo como una hoja de cálculo junto con su informe correspondiente.
#
# https://archive.ics.uci.edu/ml/datasets/Wine+Quality
# https://drive.google.com/drive/folders/1re-5B6oI4en0ro3z5zACxs_Odpiqy1WW?usp=sharing
#
# ## Describe el conjunto de datos. ¿Qué datos contiene?
#
# Esta base de datos contiene elementos que determinan la calidad del vino tinto. Entre estos elementos estan: pH, density, volatile acidity, citric acidity, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, suphates, alcohol, quality.
#
# ## Normalmente, los datos tienen un identificador que se incluye en el encabezado de la columna correspondiente. ¿Qué identificador no tiene claro su significado?¿Cómo podrías investigarlo?
#
# Los identificadores parecen verse bien se entienden perfectamente, lo unico que no se puede ver el nombre de cada vino pero en el sitio de donde saque la base de datos dice que por motivos de seguridad no se presenta.
#
# ## ¿Cuáles son algunas de las preguntas podrías responder con estos datos? Enumera al menos tres (no respondas a las preguntas).
# 1. Que factores afectan la calidad del vino tinto?
# 2. Cual es la relacion entre la cantidad de alcohol y la calidad del vino?
# 3. Cual es la relacion entre la cantidad de pH y la calidad del vino?
#
# ## Pregunta de investigación (de interés).
#
# Como afectan los diferentes componentes del vino en su calidad?
#
# ## ¿Qué stakeholder (empresa, sector de la sociedad, organismo descentralizado, gobierno, etc.) estaría interesado en las preguntas que identificaste en el punto 6?
#
# Casa Madero
