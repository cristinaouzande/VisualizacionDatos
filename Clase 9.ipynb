# %% [markdown]
# ## Clase 9: Regresion simple, multiple....

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          mic.xlsx

# %%
# %ls
# Out:
#  00_00_binder.ipynb
#  00_00_primer_pasos.ipynb
#  01_01_data_types.ipynb
#  01_02_read_iloc_unique_groupby.ipynb
#  02_00_data_wrangling.ipynb
#  02_01_null_display.ipynb
#  02_02_basic_math.ipynb
#  Act3.ipynb
# 'Actividad 5.ipynb'
# 'Actividad 6 - Presentación Intermedia (1) (1).ipynb'
# 'Actividad 7 (1) (1).ipynb'
#  adult.csv
# 'antropometria act7.csv'
#  antropometria-dataset-1.csv
#  antropometria-dataset-2.csv
# 'clase1 (1).ipynb'
#  clase1.ipynb
#  clase2.ipynb
#  clase2pt2.ipynb
#  clase3.ipynb
# 'clase 3 pt2.ipynb'
#  Clase4.ipynb
#  clase5.ipynb
#  Clase7.ipynb
#  Clase8.ipynb
# 'Clase 9.ipynb'
#  datasets/
#  ejercicio_distribuciones_datos_multivariantes.ipynb
#  README.md
#  reg_data.csv
#  requirements.txt
#  Untitled.ipynb
# 'winequality-red.xls - winequality-red.csv'

# %%
import pandas as pd

# %%
df = pd.read_csv('reg_data.csv')
df
# Out:
#     Gender  Salary  Age       Place  Weight Company Academic_degree
# 0   Female    1500   33     Chicago    80.0     BMW        Bachelor
# 1   Female    1200   33     Chicago    82.5    Ford              No
# 2     Male    2200   34    New York   100.8     BMW        Bachelor
# 3     Male    2100   42    New York    90.0     BMW          Master
# 4   Female    1500   29     Chicago    67.0    Ford          Master
# 5   Female    1700   42  Washington    60.0    Ford          Master
# 6     Male    3000   50  Washington    77.0    Ford              No
# 7     Male    3000   55  Washington    77.0    Ford        Bachelor
# 8   Female    2800   31    New York    87.0    Ford        Bachelor
# 9     Male    2900   46    New York    70.0      GM          Master
# 10  Female    2780   36  Washington    57.0     BMW              No
# 11    Male    2550   48    New York    64.0      GM          Master

# %% [markdown]
# # Introducción
#
# Este es una base de datos que exploca Salary de 12 personas de distintas empresas.
#
# ## Mis variables de interes
#
# - Gender: categorica, explica genero de los empleados y tiene dos categorias..
# - Salary: explicar variable num
# - Age: explicar
# - Academic degree: explicar

# %% [markdown]
# # 1. Pregunta de investigacion 1:
# ### Cual es el impacto de Age en Salary
# Salary = b0 + b1*Age

# %%
pip install sklearn

# %%
pip install statsmodels

# %%
pip install seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import numpy as np 
from sklearn import linear_model

# %%
modelA = sm.OLS.from_formula('Salary~Age', data = df)
resultA = modelA.fit()
resultA.summary()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/scipy/stats/stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.380
# Model:                            OLS   Adj. R-squared:                  0.319
# Method:                 Least Squares   F-statistic:                     6.142
# Date:                Tue, 30 Nov 2021   Prob (F-statistic):             0.0326
# Time:                        14:20:50   Log-Likelihood:                -91.514
# No. Observations:                  12   AIC:                             187.0
# Df Residuals:                      10   BIC:                             188.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# Salary = 349.4458 + 48.0932	*Age
# ### Observaciones:
# - Variable dependiente: Salary
# - Variable independiente: Age
# - R-squared: 0.380, modelo no tan eficiente ya que el valor esta muy cercano a 0. Esto explica que solo el 38% del salario es pasado en la edad.
#
# - Df Model:
# - intercept... >0.05, no es estadisticamente significativo
# - Age si

# %%
print('Salary of a person whose age is 33:',349.4458 + 48.0932	*33) 
df.iloc[:2,:]
# Out:
# Salary of a person whose age is 33: 1936.5214
#    Gender  Salary  Age    Place  Weight Company Academic_degree
# 0  Female    1500   33  Chicago    80.0     BMW        Bachelor
# 1  Female    1200   33  Chicago    82.5    Ford              No

# %%
print('Diferencia es:\t:', 1500-1936.5214)
print('Diferencia es:\t:', 1200-1936.5214)
resultA.resid
# Out:
# Diferencia es:	: -436.5214000000001
# Diferencia es:	: -736.5214000000001
# 0    -436.521924
# 1    -736.521924
# 2     215.384860
# 3    -269.360866
# 4    -244.149060
# 5    -669.360866
# 6     245.893407
# 7       5.427328
# 8     959.664508
# 9     338.266270
# 10    699.198429
# 11   -107.920161
# dtype: float64

# %%
plt.figure(figsize = (15,10))
sns.set(font_scale=1.7)

reg_plot = sns.regplot(x = 'Age',
            y = 'Salary',
            data = df,
            marker = '+',
            color = 'green',
           scatter_kws = {'s':200}
           )
reg_plot.set_title('Regression plot of Salary vs Age')
reg_plot.text(45, 1500, 'Salary = 349.4458 + 48.0932*Age',
             color = 'green',
             weight='semibold',
             size ='medium')
# Out:
# Text(45, 1500, 'Salary = 349.4458 + 48.0932*Age')

# %%
RESIA = resultA.resid
RESIA
# Out:
# 0    -436.521924
# 1    -736.521924
# 2     215.384860
# 3    -269.360866
# 4    -244.149060
# 5    -669.360866
# 6     245.893407
# 7       5.427328
# 8     959.664508
# 9     338.266270
# 10    699.198429
# 11   -107.920161
# dtype: float64

# %%
resi_plot = sns.scatterplot(x= resultA.fittedvalues,
                            y= RESIA)

# %% [markdown]
# ## Conclusion:
# Los residuales se observan muy dispersos

# %% [markdown]
# # Pregunta de investigacion 2:
# ### Cual es el impacto de Age y Gender en Salary
# Salary = b0 + b1*Age + b2*Gender

# %%
modelB = sm.OLS.from_formula('Salary~Age + Gender', data = df)
resultB = modelB.fit()
resultB.summary()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/scipy/stats/stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.408
# Model:                            OLS   Adj. R-squared:                  0.276
# Method:                 Least Squares   F-statistic:                     3.101
# Date:                Tue, 30 Nov 2021   Prob (F-statistic):             0.0945
# Time:                        14:20:51   Log-Likelihood:                -91.242
# No. Observations:                  12   AIC:                             188.5
# Df Residuals:                       9   BIC:                             189.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# ### Observaciones:
# - Variable dependiente: Salary
# - Variable independiente: Age, Gender
# - R-squared: 0.408, modelo no tan eficiente ya que el valor esta muy cercano a 0. Esto explica que solo el 38% del salario es pasado en la edad.
#
# - Df Model:2
# - intercept... >0.05, no es estadisticamente significativo
# - Age si
#
# Salary = 749.8157 + 34.2211*Age +306.7169*Gender_Male
#
# ## Case study:
# Df Model:2
# #### Caso 1:
# - Age = 33
# - Male = True

# %%
print('Salary de una persona con Age 33, Male\t', 749.8157 + 34.2211*33 +306.7169*1)
# Out:
# Salary de una persona con Age 33, Male	 2185.8289

# %% [markdown]
# #### Caso 2:
# - Age = 33
# - Male = False

# %%
print('Salary de una persona con Age 33, Female\t', 749.8157 + 34.2211*33 +306.7169*0)  
df.iloc[:2,:]
# Out:
# Salary de una persona con Age 33, Female	 1879.112
#    Gender  Salary  Age    Place  Weight Company Academic_degree
# 0  Female    1500   33  Chicago    80.0     BMW        Bachelor
# 1  Female    1200   33  Chicago    82.5    Ford              No

# %%
resultB.resid
# Out:
# 0    -379.112228
# 1    -679.112228
# 2     -20.050251
# 3    -393.819095
# 4    -242.227806
# 5    -487.102178
# 6     232.412060
# 7      61.306533
# 8     989.329983
# 9     269.296482
# 10    798.224456
# 11   -149.145729
# dtype: float64

# %% [markdown]
# # Pregunta de investigacion 3:
# ### Cual es el impacto de Age, Gender, Academic_Degree en Salary
# Salary = b0 + b1*Age + b2*Gender + b3*Academic_degree

# %%
modelC = sm.OLS.from_formula('Salary~Age + Gender + Academic_degree', data = df)
resultC = modelC.fit()
resultC.summary()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/scipy/stats/stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.483
# Model:                            OLS   Adj. R-squared:                  0.188
# Method:                 Least Squares   F-statistic:                     1.636
# Date:                Tue, 30 Nov 2021   Prob (F-statistic):              0.267
# Time:                        14:24:30   Log-Likelihood:                -90.426
# No. Observations:                  12   AIC:                             190.9
# Df Residuals:                       7   BIC:                             193.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# ### Observaciones:
# - Variable dependiente: Salary
# - Variable independiente: Age, Gender, Academic_degree
# - R-squared: 0.483, modelo no tan eficiente ya que el valor esta muy cercano a 0. Esto explica que solo el 48% del salario es pasado en la edad.
#
# - Df Model:4
#
# Salary = 815.5485 + 36.376*Age +336.1028*Gender_Male - 373.1962*ADMaster - 43.8495*ADNo
#
# ## Case study:
# Df Model:4
# #### Caso 1
# - Age = 48
# - Male = True
# - ADMaster = True
# - ADNo = False

# %%
print('Salary de una persona con Age 48, Male, tiene Master Degree\t',815.5485 + 36.376*48 +336.1028*1 - 373.1962*1 - 43.8495*0)   
df.iloc[-1:,:]
# Out:
# Salary de una persona con Age 48, Male, tiene Master Degree	 2524.5031
#    Gender  Salary  Age     Place  Weight Company Academic_degree
# 11   Male    2550   48  New York    64.0      GM          Master

# %% [markdown]
# #### Caso 2
# - Age = 33
# - Male = False
# - ADMaster = False
# - ADNo = False

# %%
print('Salary de una persona con Age 33, Female, tiene Bachelors Degree\t',815.5485 + 36.376*33 +336.1028*0 - 373.1962*0 - 43.8495*0)   
df.iloc[:2,:]
# Out:
# Salary de una persona con Age 33, Female, tiene Bachelors Degree	 2015.9564999999998
#    Gender  Salary  Age    Place  Weight Company Academic_degree
# 0  Female    1500   33  Chicago    80.0     BMW        Bachelor
# 1  Female    1200   33  Chicago    82.5    Ford              No

# %%
resultC.resid
# Out:
# 0    -515.972096
# 1    -772.122563
# 2    -188.451404
# 3    -206.267018
# 4       2.729975
# 5    -270.164184
# 6      73.374548
# 7    -152.357353
# 8     856.780852
# 9     448.227087
# 10    698.748015
# 11     25.474139
# dtype: float64

# %% [markdown]
# # Pregunta de investigacion 4:
# ### Cual es el impacto de Gender, Academic_Degree en Salary
# Salary = b0 + b1*Gender + b2*Academic_degree

# %%
modelD = sm.OLS.from_formula('Salary~ Gender + Academic_degree', data = df)
resultD = modelD.fit()
resultD.summary()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/scipy/stats/stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.388
# Model:                            OLS   Adj. R-squared:                  0.158
# Method:                 Least Squares   F-statistic:                     1.689
# Date:                Tue, 30 Nov 2021   Prob (F-statistic):              0.246
# Time:                        14:39:36   Log-Likelihood:                -91.443
# No. Observations:                  12   AIC:                             190.9
# Df Residuals:                       8   BIC:                             192.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# ### Observaciones:
# - Variable dependiente: Salary
# - Variable independiente: Gender, Academic_degree
# - R-squared: 0.388, modelo no tan eficiente ya que el valor esta muy cercano a 0. Esto explica que solo el 38.8% del salario es pasado en el genero y en el academic degree.
#
# - Df Model=3
#
# Salary = 1987.2093 + 775.5814*Gender_Male - 302.5581*ADMasters + 80.9302*ADNo
#
# ## Case study:
# Df Model:3
# #### Caso 1
# - Male = False
# - ADMaster = False
# - ADNo = False

# %%
print('Salary de una persona  Female, tiene Bachelors Degree\t',1987.2093 + 775.5814*0- 302.5581*0 + 80.9302*0)   
df.iloc[:2,:]
# Out:
# Salary de una persona  Female, tiene Bachelors Degree	 1987.2093
#    Gender  Salary  Age    Place  Weight Company Academic_degree
# 0  Female    1500   33  Chicago    80.0     BMW        Bachelor
# 1  Female    1200   33  Chicago    82.5    Ford              No

# %%
resultC.resid
# Out:
# 0    -515.972096
# 1    -772.122563
# 2    -188.451404
# 3    -206.267018
# 4       2.729975
# 5    -270.164184
# 6      73.374548
# 7    -152.357353
# 8     856.780852
# 9     448.227087
# 10    698.748015
# 11     25.474139
# dtype: float64
